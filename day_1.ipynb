# %% [markdown]
# <a href="https://colab.research.google.com/github/supermario64bit/scaler_ai_ml_resources/blob/main/day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
